# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql  import *
from pyspark.sql.functions  import *
from pyspark.sql.types  import *
# Out:
# StatementMeta(, 53d19ac8-f916-4978-8b48-29d28bcc9961, 6, Finished, Available)

# %%
# %%sql
# create table if not EXISTS lh_ecormece.Gold_DimDate
# (
#     BusinessDate Date,
#     Business_Year int,
#     Business_Month int,
#     Business_Quarter int,
#     Business_Week int
# )
# using DELTA
# PARTITIONED by (Business_Year)
# Out:
# StatementMeta(, 53d19ac8-f916-4978-8b48-29d28bcc9961, 7, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
start_date='2015-01-01'
end_date='2030-12-31'

date_diff=spark.sql("select date_diff('{}','{}')".format(end_date,start_date)).first()[0]
date_diff
# Out:
# StatementMeta(, 53d19ac8-f916-4978-8b48-29d28bcc9961, 8, Finished, Available)
# 5843

# %%
ID_Data=spark.range(0,date_diff)
# Out:
# StatementMeta(, 53d19ac8-f916-4978-8b48-29d28bcc9961, 10, Finished, Available)

# %%
date_data=ID_Data.selectExpr("date_add('{}',cast(id as int)) as BusinessDate".format(start_date))
# Out:
# StatementMeta(, 53d19ac8-f916-4978-8b48-29d28bcc9961, 11, Finished, Available)

# %%
date_data.createOrReplaceTempView("ViewDate")
# Out:
# StatementMeta(, 53d19ac8-f916-4978-8b48-29d28bcc9961, 12, Finished, Available)

# %%
# %%sql
# insert into lh_ecormece.gold_dimdate
# select *,
#     Year(BusinessDate) as Business_Year,
#     Month(BusinessDate) as Business_Month,
#     Quarter(BusinessDate) as Business_Quarter,
#     weekday(BusinessDate) as Business_Week
#  from ViewDate
# Out:
# StatementMeta(, 53d19ac8-f916-4978-8b48-29d28bcc9961, 15, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>
