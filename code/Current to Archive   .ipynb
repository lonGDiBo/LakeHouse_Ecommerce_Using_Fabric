# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, 8b1c5b45-2c9b-456d-bec1-bc98e4732322, 3, Finished, Available)

# %%
mssparkutils.fs.mount("abfss://fb9f6c83-5ff0-46a3-9b49-0a37dbafa509@onelake.dfs.fabric.microsoft.com/fac3800b-7a90-47b1-ab86-fa4ccea42f00/Files","/Files")
# Out:
# StatementMeta(, 8b1c5b45-2c9b-456d-bec1-bc98e4732322, 4, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 2e63f7b2-90eb-47a6-bb46-da81ebd83551)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, 8b1c5b45-2c9b-456d-bec1-bc98e4732322, 5, Finished, Available)
# '/synfs/notebook/8b1c5b45-2c9b-456d-bec1-bc98e4732322/Files'

# %%
check_files_current=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/Current/")
# Out:
# StatementMeta(, 8b1c5b45-2c9b-456d-bec1-bc98e4732322, 6, Finished, Available)

# %%
check_files_current
# Out:
# StatementMeta(, 8b1c5b45-2c9b-456d-bec1-bc98e4732322, 7, Finished, Available)
# [FileInfo(path=file:/synfs/notebook/8b1c5b45-2c9b-456d-bec1-bc98e4732322/Files/Current/Sales_02012023.xlsx, name=Sales_02012023.xlsx, size=498608)]

# %%
check_files_archive=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/Archive/")
# Out:
# StatementMeta(, 8b1c5b45-2c9b-456d-bec1-bc98e4732322, 9, Finished, Available)

# %%
file_names_archive = [file_info.name for file_info in check_files_archive]
file_names_archive
# Out:
# StatementMeta(, 8b1c5b45-2c9b-456d-bec1-bc98e4732322, 10, Finished, Available)
# ['Sales_01012023.xlsx', 'Sales_02012023.xlsx', 'Sales_04012023.xlsx']

# %%
for file in check_files_current:
    if file.path:
        if file.name not in file_names_archive:
            mssparkutils.fs.mv(file.path, f"file://{mssparkutils.fs.getMountPath('/Files')}/Archive/")
        else:
            mssparkutils.fs.rm(file.path)
# Out:
# StatementMeta(, 8b1c5b45-2c9b-456d-bec1-bc98e4732322, 11, Finished, Available)
