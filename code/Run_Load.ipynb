# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, 398204c9-6a93-4ce9-a501-a23a136ecaae, 4, Finished, Available)

# %%
mssparkutils.fs.mount("abfss://fb9f6c83-5ff0-46a3-9b49-0a37dbafa509@onelake.dfs.fabric.microsoft.com/fac3800b-7a90-47b1-ab86-fa4ccea42f00/Files","/Files")
# Out:
# StatementMeta(, 398204c9-6a93-4ce9-a501-a23a136ecaae, 5, Finished, Available)
# SynapseWidget(Synapse.DataFrame, be69a3bf-a71a-4294-b184-5203598c970e)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, 398204c9-6a93-4ce9-a501-a23a136ecaae, 6, Finished, Available)
# '/synfs/notebook/398204c9-6a93-4ce9-a501-a23a136ecaae/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/Current/")
# Out:
# StatementMeta(, 398204c9-6a93-4ce9-a501-a23a136ecaae, 7, Finished, Available)

# %%
check_files
# Out:
# StatementMeta(, 398204c9-6a93-4ce9-a501-a23a136ecaae, 8, Finished, Available)
# [FileInfo(path=file:/synfs/notebook/398204c9-6a93-4ce9-a501-a23a136ecaae/Files/Current/Sales_04012023.xlsx, name=Sales_04012023.xlsx, size=535106)]

# %%
if check_files:
    mssparkutils.notebook.run("Bronze_Sales")
    mssparkutils.notebook.run("Gold_Customer")
    mssparkutils.notebook.run("Gold_Date")
    mssparkutils.notebook.run("Gold_Product")
    mssparkutils.notebook.run("Gold_Shipmode")
    mssparkutils.notebook.run("Gold_Orderpriority")
    mssparkutils.notebook.run("Gold_Orderreturn")
    mssparkutils.notebook.run("Gold_FactSale")
    mssparkutils.notebook.run("Current to Archive")
# Out:
# StatementMeta(, 398204c9-6a93-4ce9-a501-a23a136ecaae, 15, Finished, Available)
