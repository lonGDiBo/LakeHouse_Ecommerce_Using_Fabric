# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, d4c45f1c-581e-40ac-be70-9e6e28b68eaa, 3, Finished, Available)

# %%
# %%sql
#
# create table if not exists lh_ecormece.Gold_DimOrderReturn
# (
#
# Order_ID  string,
# Return string,
# Order_Year int,
# Order_Month int,
# Created_TS TIMESTAMP,
# Modified_TS TIMESTAMP
#
# )
# using delta
# partitioned by(Order_Year,Order_Month)
# Out:
# StatementMeta(, d4c45f1c-581e-40ac-be70-9e6e28b68eaa, 6, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
max_date = spark.sql("SELECT coalesce(max(Modified_TS),'1900-01-01') from lh_ecormece.Gold_DimOrderReturn").first()[0]
# Out:
# StatementMeta(, d4c45f1c-581e-40ac-be70-9e6e28b68eaa, 9, Finished, Available)

# %%
max_date
# Out:
# StatementMeta(, d4c45f1c-581e-40ac-be70-9e6e28b68eaa, 10, Finished, Available)
# '1900-01-01'

# %%
df=spark.sql("""select Order_ID  ,
Return ,
Order_Year, 
Order_Month ,
Created_TS ,
Modified_TS 
from lh_ecormece.bronze_sales where Return="Yes" and Modified_TS>'{}'""".format(max_date))
# Out:
# StatementMeta(, d4c45f1c-581e-40ac-be70-9e6e28b68eaa, 13, Finished, Available)

# %%
display(df.head(10))
# Out:
# StatementMeta(, d4c45f1c-581e-40ac-be70-9e6e28b68eaa, 14, Finished, Available)
# SynapseWidget(Synapse.DataFrame, dccac6db-8d00-4ab8-9ca4-9e9447701f7b)

# %%
df.createOrReplaceTempView('View_orderReturn')
# Out:
# StatementMeta(, d4c45f1c-581e-40ac-be70-9e6e28b68eaa, 16, Finished, Available)

# %%
# %%sql
# INSERT INTO lh_ecormece.gold_dimorderreturn
# SELECT * from View_orderReturn
# Out:
# StatementMeta(, d4c45f1c-581e-40ac-be70-9e6e28b68eaa, 17, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>
